# %%
#conversation.ipynb
from dotenv import load_dotenv
load_dotenv()
from src.graph import build_graph
from langgraph import graph
from langchain_openai import ChatOpenAI

# %%
app = build_graph().compile()

llm = ChatOpenAI(
    model="gpt-4o-mini",
)

llm.invoke("Hello")
# Out:
# AIMessage(content='Hello! How can I assist you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 9, 'prompt_tokens': 8, 'total_tokens': 17, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_e9323266c1', 'id': 'chatcmpl-E0txvbHmVeQRVe51ppwXkn1LOk37j', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f57c3-2fc7-7871-afb2-d243f8bd9d8b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8, 'output_tokens': 9, 'total_tokens': 17, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
from src.tools import search_tool

search_tool.invoke("What is Today's Tokyo weather?")
# Out:
# [{'snippet': "Be prepared for Tokyo, Japan's weather with this hourly forecast. Hour by hour predictions for temps, rain/snow chances, wind, dew point and more for the next 24-48 hours.",
#   'title': 'Tokyo, Japan Hourly Weather Forecast - WeatherWorld.com',
#   'link': 'https://www.weatherworld.com/hourly-weather/jp/tokyo.html'},
#  {'snippet': '12 day Tokyo, Japan Weather Forecast. Live Weather Warnings, hourly weather updates. Accurate Tokyo weather today, forecast for sun, rain, wind and temperature.',
#   'title': 'Tokyo, Japan Weather Forecast',
#   'link': 'https://www.weather-forecast.com/locations/Tokyo-1/forecasts/latest'},
#  {'snippet': 'Current weather in Tokyo, Tokyo, Japan. Check current conditions in Tokyo, Tokyo, Japan with radar, hourly, and more.',
#   'title': 'Tokyo, Tokyo, Japan Current Weather | AccuWeather',
#   'link': 'https://www.accuweather.com/en/jp/tokyo/226396/current-weather/226396'},
# ...

# %%
from src.nodes import conversation_node

conversation_node(
    {
        "user_input": "こんにちは！いい朝ですね！今日は寿司に食べますか？"
    }
)
# Out:
# {'feedback': None, 'need_web_search': False, 'search_query': None}

# %%
from src.nodes import response_node

response_node(
    {
        "user_input": "こんにちは！",
        "search_result": None,
    }
)
# Out:
# {'reply': 'こんにちは！元気ですか？'}

# %%
from src.graph import build_graph

graph = build_graph()

app = graph.compile()

app

# %%
result = app.invoke(
    {
        "user_input": "こんにちは！"
    }
)

# %%
result
# Out:
# {'user_input': 'こんにちは！',
#  'reply': 'こんにちは！元気ですか？',
#  'feedback': None,
#  'need_web_search': False,
#  'search_query': None}
